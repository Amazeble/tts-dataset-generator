# %%
# !apt update
# !apt install ffmpeg

# %%
# Clone this repository
# !git clone https://github.com/gokhaneraslan/tts-dataset-generator.git

# %%
# %cd tts-dataset-generator

# %%
# Install dependencies
pip install -r requirements.txt

# %%
# Upload your audio/video file to /content/ folder using Colab's file uploader
# Then run the cells below with your actual file path and sample rate

# %%
# Replace 'your_audio_or_video_file.mp4' with your actual file name and sample rate
# !python main.py --file /content/your_audio_or_video_file.mp4 --model large --language tr --sample_rate 22050

# %%
# For LJSpeech format - replace with your actual file name
# !python main.py --file /content/your_audio_or_video_file.mp4 --model large --language tr --ljspeech True --sample_rate 22050
